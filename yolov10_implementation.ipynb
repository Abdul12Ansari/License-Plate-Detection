# %%
# !python --version
# Out:
# Python 3.12.4

# %% [markdown]
# ### Download repo and installing required packages

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# fatal: destination path 'yolov10' already exists and is not an empty directory.

# %%
cd yolov10
# Out:
# C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\yolov10

# %%
# !pip install .
# Out:
# Processing c:\users\92304\desktop\yolov10-custom-object-detection-main\yolov10
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=735415 sha256=2d4787e7e6da0a5f66c6a4754a8b2a14938e63fe52baab70fc99089bdc1c58eb
#   Stored in directory: C:\Users\92304\AppData\Local\Temp\pip-ephem-wheel-cache-vc4z35c7\wheels\b4\c9\a5\84f8e59f6914c2a76bddf0303e51bc5e99c56e7b33bb5c69cc
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...

# %% [markdown]
# ### Downloading pretrained weights

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\yolov10\weights\yolov10n.pt
# Downloaded C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\yolov10\weights\yolov10s.pt
# Downloaded C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\yolov10\weights\yolov10m.pt
# Downloaded C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\yolov10\weights\yolov10b.pt
# Downloaded C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\yolov10\weights\yolov10x.pt
# Downloaded C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\yolov10\weights\yolov10l.pt

# %% [markdown]
# # Inference using pretrained model

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=../weights/yolov10n.pt source=../test_images/1.jpg
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.4.0+cpu CPU (Intel Core(TM) i7-6600U 2.60GHz)
# YOLOv10n summary (fused): 285 layers, 2762608 parameters, 63840 gradients, 8.6 GFLOPs
#
# image 1/1 C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\yolov10\..\test_images\1.jpg: 448x640 4 17s, 157.6ms
# Speed: 4.0ms preprocess, 157.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict5
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict
# ...

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# %% [markdown]
# # Train Custom Model

# %%
# !yolo task=detect mode=train epochs=1000 batch=16 plots=True model=weights/yolov10n.pt data=C:/Users/92304/Desktop/YOLOv10-Custom-Object-Detection-main/custom_data.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.3.13 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.4.0+cpu CPU (Intel Core(TM) i7-6600U 2.60GHz)
# ...

# %% [markdown]
# # Inference

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=C:/Users/92304/Desktop/YOLOv10-Custom-Object-Detection-main/testimages/veh2.jpg
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.4.0+cpu CPU (Intel Core(TM) i7-6600U 2.60GHz)
# YOLOv10n summary (fused): 285 layers, 2694806 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/1 C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\testimages\veh2.jpg: 512x640 (no detections), 163.3ms
# Speed: 6.6ms preprocess, 163.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs\detect\predict6
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict
# ...

# %% [markdown]
# # Inference on Video

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=C:/Users/92304/Desktop/YOLOv10-Custom-Object-Detection-main/b.mp4
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.4.0+cpu CPU (Intel Core(TM) i7-6600U 2.60GHz)
# YOLOv10n summary (fused): 285 layers, 2694806 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/348) C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\b.mp4: 384x640 (no detections), 121.3ms
# video 1/1 (frame 2/348) C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\b.mp4: 384x640 (no detections), 110.9ms
# video 1/1 (frame 3/348) C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\b.mp4: 384x640 (no detections), 110.5ms
# video 1/1 (frame 4/348) C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\b.mp4: 384x640 (no detections), 121.1ms
# video 1/1 (frame 5/348) C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\b.mp4: 384x640 (no detections), 122.1ms
# video 1/1 (frame 6/348) C:\Users\92304\Desktop\YOLOv10-Custom-Object-Detection-main\b.mp4: 384x640 (no detections), 123.1ms
# ...
